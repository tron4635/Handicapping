# %%
import pandas as pd
import sqlite3

# %%
# Create a SQL connection to our SQLite database
con = sqlite3.connect("hkjc.db")
cur = con.cursor()

# %%
# Return all results of query
cur.execute('SELECT * FROM horses')
cur.fetchall()

# Return first result of query
#cur.fetchone()

# %%
horses = pd.read_sql_query("SELECT * FROM horses", con)

# %%
horses.head()
# Out:
#         horseid horsename country    colour      sex importtype  \
# 0  HK_2006_H093    MY SAY     AUS     Brown  Gelding         PP
# 1  HK_2007_J203    MY WAY      NZ       Bay  Gelding        PPG
# 2  HK_1982_T089    MY WAY     IRE  Chestnut  Gelding         SG
# 3  HK_1996_P149    MY WAY     USA     Brown  Gelding         PP
# 4  HK_2014_T244    MY HAY     AUS  Chestnut  Gelding        PPG
#
#                  owner           sire                dam      damsire  \
# 0           Ip Chi Kin      Canny Lad         Vale Nymph  Avon Valley
# 1  Anthony Wu Ting Yuk         Danske            Timpani      Maizcay
# 2                       Majority Blue       Gentle Enemy
# 3      Dr Chang Fuk To     Red Ransom     What Not To Do    What Luck
# 4   Kenneth Wu Pak Kei         Freeze  Alleged Encounter    Encounter
#
#                                                  url  age
# 0  https://racing.hkjc.com/racing/information/eng...  NaN
# ...

# %%
horseraces = pd.read_sql_query("SELECT * FROM horsesraces", con)

# %%
horseraces.head()
# Out:
#         horseid                    raceid place  draw  rating       trainer  \
# 0  HK_2010_M401  2015-12-16-257-2200-Turf    01   7.0    50.0  P O'Sullivan
# 1  HK_2012_P405  2017-10-29-145-2200-Turf    01   5.0    30.0         A Lee
# 2  HK_2012_P405  2015-04-29-575-2200-Turf    01   7.0    43.0         A Lee
# 3  HK_2012_P405  2015-02-25-414-2200-Turf    01   3.0    37.0         A Lee
# 4  HK_2006_H097  2009-03-18-473-2200-Turf    01   2.0    65.0      C Fownes
#
#       jockey lengthbehindwinner  winodds  actualweight  position1  position2  \
# 0  J Moreira                 HD      3.6           128        8.0        8.0
# 1  M L Yeung              1-1/4      5.8           128        9.0        6.0
# 2  M L Yeung                1/2      4.2           114        9.0        9.0
# 3  M L Yeung                  N     17.0           111       10.0       11.0
# 4  B Prebble                  N      4.9           121        7.0        6.0
#
# ...

# %%
horseraces.loc[horseraces['raceid'] == "2021-05-05-651-1200-Turf"]
# Out:
#              horseid                    raceid place  draw  rating  \
# 319098  HK_2017_B402  2021-05-05-651-1200-Turf    03   7.0    82.0
# 319108  HK_2019_D197  2021-05-05-651-1200-Turf    10  11.0    87.0
# 319170  HK_2018_C082  2021-05-05-651-1200-Turf    06   8.0    83.0
# 319256  HK_2017_B119  2021-05-05-651-1200-Turf    01   3.0    88.0
# 319349  HK_2019_D481  2021-05-05-651-1200-Turf    02   4.0    82.0
# 319358  HK_2018_C058  2021-05-05-651-1200-Turf    04   1.0    92.0
# 319384  HK_2018_C037  2021-05-05-651-1200-Turf    07   6.0    80.0
# 319415  HK_2019_D147  2021-05-05-651-1200-Turf    05  10.0    96.0
# 319438  HK_2017_B377  2021-05-05-651-1200-Turf    09   9.0    83.0
# 319503  HK_2018_C299  2021-05-05-651-1200-Turf    08   5.0    84.0
# 319526  HK_2017_B025  2021-05-05-651-1200-Turf    12   2.0    90.0
# 319601  HK_2019_D093  2021-05-05-651-1200-Turf    11  12.0    99.0
#
#              trainer       jockey lengthbehindwinner  winodds  actualweight  \
# ...

# %%
races = pd.read_sql_query("SELECT * FROM races", con)

# %%
races = races.sort_values('racedate', ascending=False)

races.head()
# Out:
#                          raceid raceidseason    racedate racetrack tracktype  \
# 26567  2021-05-05-651-1200-Turf          651  2021-05-05        HV      Turf
# 26566  2021-05-05-649-1200-Turf          649  2021-05-05        HV      Turf
# 26548  2021-05-05-645-1000-Turf          645  2021-05-05        HV      Turf
# 26549  2021-05-05-644-1650-Turf          644  2021-05-05        HV      Turf
# 26550  2021-05-05-646-1200-Turf          646  2021-05-05        HV      Turf
#
#       course  distance going raceclass
# 26567      A      1200    GF         2
# 26566      A      1200    GF         3
# 26548      A      1000    GF         4
# 26549      A      1650     G         3
# 26550      A      1200    GF         4

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26568 entries, 0 to 26567
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   raceid        26568 non-null  object
#  1   raceidseason  26568 non-null  object
#  2   racedate      26568 non-null  object
#  3   racetrack     26568 non-null  object
#  4   tracktype     26568 non-null  object
#  5   course        21804 non-null  object
#  6   distance      26568 non-null  int64
#  7   going         26568 non-null  object
#  8   raceclass     26568 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.8+ MB

# %%
# Be sure to close the connection
con.close()
